# %%
from cmapPy.pandasGEXpress.parse_gct import parse
from cmapPy.pandasGEXpress.write_gct import write

import numpy as np
from scipy.stats import spearmanr
from statsmodels.stats.multitest import multipletests

# %%
data = parse('GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_median_tpm.gct', ridx=[i for i in range(10000)])
data.row_metadata_df.dropna(inplace=True)
data.data_df = data.data_df.loc[data.row_metadata_df.index]
dataset = data.data_df

print(len(dataset))
# Out:
# 10000

# %%
#To remove all entries for whom all values are 0, to prevent corr and p being NaN
for i in dataset.index.values:
    if np.sum(dataset.loc[i].values) == 0.0:
        dataset = dataset.drop(i, axis=0)
            
print(len(dataset))
# Out:
# 8001

# %%
p_values = []
corr_values = []

count = 0
for i in dataset.index.values:
    for j in dataset.index.values:
        
        count = count + 1
        if(count%1000 == 0):
            print(count)

        gene1 = dataset.loc[i].values
        gene2 = dataset.loc[j].values
        
        corr, p = spearmanr(gene1, gene2)
        
        corr_values.append(corr)
        p_values.append(p)

#print(corr_values)
#print(p_values)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 223000
# 224000
# 225000
# 226000
# 227000
# 228000
# 229000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 243000
# 244000
# 245000
# 246000
# 247000
# 248000
# 249000
# 250000
# 251000
# 252000
# 253000
# 254000
# 255000
# 256000
# 257000
# 258000
# 259000
# 260000
# 261000
# 262000
# 263000
# 264000
# 265000
# 266000
# 267000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 274000
# 275000
# 276000
# 277000
# 278000
# 279000
# 280000
# 281000
# 282000
# 283000
# 284000
# 285000
# 286000
# 287000
# 288000
# 289000
# 290000
# 291000
# 292000
# 293000
# 294000
# 295000
# 296000
# 297000
# 298000
# 299000
# 300000
# 301000
# 302000
# 303000
# 304000
# 305000
# 306000
# 307000
# 308000
# 309000
# 310000
# 311000
# 312000
# 313000
# 314000
# 315000
# 316000
# 317000
# 318000
# 319000
# 320000
# 321000
# 322000
# 323000
# 324000
# 325000
# 326000
# 327000
# 328000
# 329000
# 330000
# 331000
# 332000
# 333000
# 334000
# 335000
# 336000
# 337000
# 338000
# 339000
# 340000
# 341000
# 342000
# 343000
# 344000
# 345000
# 346000
# 347000
# 348000
# 349000
# 350000
# 351000
# 352000
# 353000
# 354000
# 355000
# 356000
# 357000
# 358000
# 359000
# 360000
# 361000
# 362000
# 363000
# 364000
# 365000
# 366000
# 367000
# 368000
# 369000
# 370000
# 371000
# 372000
# 373000
# 374000
# 375000
# 376000
# 377000
# 378000
# 379000
# 380000
# 381000
# 382000
# 383000
# 384000
# 385000
# 386000
# 387000
# 388000
# 389000
# 390000
# 391000
# 392000
# 393000
# 394000
# 395000
# 396000
# 397000
# 398000
# 399000
# 400000
# 401000
# 402000
# 403000
# 404000
# 405000
# 406000
# 407000
# 408000
# 409000
# 410000
# 411000
# 412000
# 413000
# 414000
# 415000
# 416000
# 417000
# 418000
# 419000
# 420000
# 421000
# 422000
# 423000
# 424000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1b4e09803fad> in <module>
#      13         gene2 = dataset.loc[j].values
#      14
# ---> 15         corr, p = spearmanr(gene1, gene2)
#      16
#      17         corr_values.append(corr)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in spearmanr(a, b, axis, nan_policy)
#    3741                 variable_has_nan = np.isnan(a).sum(axis=axisout)
#    3742
# -> 3743     a_ranked = np.apply_along_axis(rankdata, axisout, a)
#    3744     rs = np.corrcoef(a_ranked, rowvar=axisout)
#    3745     dof = n_obs - 2  # degrees of freedom
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     369     # compute indices for the iteration axes, and append a trailing ellipsis to
#     370     # prevent 0d arrays decaying to scalars, which fixes gh-8642
# --> 371     inds = ndindex(inarr_view.shape[:-1])
#     372     inds = (ind + (Ellipsis,) for ind in inds)
#     373
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/index_tricks.py in __init__(self, *shape)
#     638             shape = shape[0]
#     639         x = as_strided(_nx.zeros(1), shape=shape,
# --> 640                        strides=_nx.zeros_like(shape))
#     641         self._it = _nx.nditer(x, flags=['multi_index', 'zerosize_ok'],
#     642                               order='C')
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in as_strided(x, shape, strides, subok, writeable)
#      99         interface['shape'] = tuple(shape)
#     100     if strides is not None:
# --> 101         interface['strides'] = tuple(strides)
#     102
#     103     array = np.asarray(DummyArray(interface, base=x))
#
# KeyboardInterrupt:

# %%
results = multipletests(p_values, alpha = 0.05, method='fdr_bh')
reject = results[0]
p_values_corrected = results[1]
results

# %%
#Making the Graph. It is a dictionary of the form {gene : [array of genes to which it has an edge]}
G = {}

for i in range(len(dataset)):
    temp = []
    for j in range(len(dataset)):
        if corr_values[i*len(dataset) + j] > 0.1 and not reject[i*len(dataset) + j]:  #If its greater than cutoff and not rejected during multiple test correction
            temp.append(dataset.index[j])
            
    G.update({dataset.index[i] : temp})
    
G
# Out:
# {'ENSG00000223972.5': ['ENSG00000238009.6', 'ENSG00000233750.3'],
#  'ENSG00000227232.5': [],
#  'ENSG00000243485.5': ['ENSG00000238009.6'],
#  'ENSG00000268020.3': [],
#  'ENSG00000240361.1': [],
#  'ENSG00000186092.4': [],
#  'ENSG00000238009.6': ['ENSG00000223972.5', 'ENSG00000243485.5'],
#  'ENSG00000233750.3': ['ENSG00000223972.5']}
