# %%
from cmapPy.pandasGEXpress.parse_gct import parse
from cmapPy.pandasGEXpress.write_gct import write

import networkx as nx
import pickle
import numpy as np
from scipy.stats import spearmanr
from statsmodels.stats.multitest import multipletests

# %%
data = parse('GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_gene_tpm.gct', ridx=[i for i in range(100)]) #Get the 1st 100 values 
data.row_metadata_df.dropna(inplace=True)
data.data_df = data.data_df.loc[data.row_metadata_df.index]
dataset = data.data_df

print(len(dataset))
for i in dataset.index.values:
    if np.sum(dataset.loc[i].values) == 0.0:
        dataset = dataset.drop(i, axis=0)
            
print(len(dataset))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_na_list()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._ensure_encoded()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
import pandas as pd
def logic(x):
    return (x < 56000 or x > 56206)

# %%
df = pd.read_csv('GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_gene_tpm.gct',sep = '\t', header = 2 , nrows = 100)

# %%
df
# Out:
#                   Name  Description  GTEX-1117F-0226-SM-5GZZ7  \
# 0    ENSG00000223972.4      DDX11L1                   0.10820
# 1    ENSG00000227232.4       WASH7P                  21.40000
# 2    ENSG00000243485.2   MIR1302-11                   0.16020
# 3    ENSG00000237613.2      FAM138A                   0.05045
# 4    ENSG00000268020.2       OR4G4P                   0.00000
# ..                 ...          ...                       ...
# 95  ENSG00000127054.14       CPSF3L                  58.42000
# 96   ENSG00000240731.1  RP5-890O3.9                  28.04000
# 97   ENSG00000224051.2       GLTPD1                  27.55000
# 98   ENSG00000169962.4       TAS1R3                   0.94010
# 99  ENSG00000107404.13         DVL1                  75.75000
#
#     GTEX-111CU-1826-SM-5GZYN  GTEX-111FC-0226-SM-5N9B8  \
# 0                    0.11580                   0.02104
# 1                   11.03000                  16.75000
# ...

# %%
df.iloc[0]
# Out:
# 56202    GTEX-ZXES-0005-SM-57WCB
# 11688    GTEX-ZXG5-0005-SM-57WCN
# ...
